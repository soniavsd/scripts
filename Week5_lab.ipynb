# %%
import numpy as np

# %%
data=np.loadtxt(fname='../Developer/repos/eeb-c177-homework/lab-exercises/week-four/inflammation-01.csv',delimiter=',')

# %%
import matplotlib.pyplot as plt

# %%
image = plt.imshow(data)
plt.show()

# %%
ave_inflammation = np.mean(data, axis=0)
#mean along rows=0 along columns =1
ave_plot = plt.plot(ave_inflammation)
plt.xlabel('time(days)')
plt.ylabel('inflammation score')
plt.title('patient data')
plt.show()

# %%
max_plot=plt.plot(np.max(data, axis =0))
#for each data, the max inflam score recored plt.show()

# %%
fig = plt.figure(figsize=(10.0,3.0))

sbplt1=fig.add_subplot(1,3,1)
sbplt2=fig.add_subplot(1,3,2)
sbplt3=fig.add_subplot(1,3,3)

sbplt1.set_ylabel('average')
#can also add x label same way as above('time (days)') instead of average
sbplt1.plot(np.mean(data,axis=0))

sbplt2.set_ylabel('max')
sbplt2.plot(np.max(data,axis=0))

sbplt3.set_ylabel('min')
sbplt3.plot(np.min(data,axis=0))

fig.tight_layout()

plt.show()

# %%
word= 'lead'

# %%
print(word)
# Out:
# lead

# %%
print(word[0])
print(word[1])
# Out:
# l
# e

# %%
for char in word:
    print("hi", char)
# Out:
# hi l
# hi e
# hi a
# hi d

# %%
newword="oxygen"
for char in newword:
    counter=0
    counter = counter +1
    print(counter,": ",char)
# Out:
# 1 :  o
# 1 :  x
# 1 :  y
# 1 :  g
# 1 :  e
# 1 :  n

# %%
for counter, char in enumerate(newword):
    #if you want to add one to it every time, can say counter+=
    print(counter,':',char)
    counter += 1
# Out:
# 0 : o
# 1 : x
# 2 : y
# 3 : g
# 4 : e
# 5 : n

# %%
letter = 'z'
for letter in 'abc' :
    print(letter)
# Out:
# a
# b
# c

# %%
#Lists

# %%
odds= [1,3,5,7]
print('odds are:', odds)
# Out:
# odds are: [1, 3, 5, 7]

# %%
print('first element:', odds[0])
# Out:
# first element: 1

# %%
print('last element:', odds[-1])
# Out:
# last element: 7

# %%
for numbers in odds:
    print(numbers)
# Out:
# 1
# 3
# 5
# 7

# %%
names = ['Curie', 'Darwing', 'Turing']
print('names in list originally', names)
names[1] = 'Darwin'
print('new names list', names)
# Out:
# names in list originally ['Curie', 'Darwing', 'Turing']
# new names list ['Curie', 'Darwin', 'Turing']

# %%
print(names[0])
# Out:
# Curie

# %%
#pointers: a way you reference a location in memory

# %%
salsa= ['a','b','c','d']

# %%
my_salsa = list(salsa)

# %%
#my_salsa and salsa are now indepedent of each other, so if you change salsa, you wont change my_salsa

# %%
#(deep copy)

# %%
#nested lists

# %%
x = ['pepper', 'zuchinni', 'onion'], ['cabbage', 'lettuce', 'garlic'], ['apple', 'banana', 'pear']

# %%
#extracting a new nested list with just the first sublist
print([x[0]])
# Out:
# [['pepper', 'zuchinni', 'onion']]

# %%
#extract a new single list object
print(x[0])
# Out:
# ['pepper', 'zuchinni', 'onion']

# %%
#just character string of pepper
print(x[0][0])
# Out:
# pepper

# %%
print(x[0][0][1])
# Out:
# e

# %%
#how to add to a list: the append fxn

# %%
odds.append(9)

# %%
print(odds)
# Out:
# [1, 3, 5, 7, 9]

# %%
#to remove from list: pop

# %%
odds.pop()
print(odds)
# Out:
# [1, 3, 5, 7]

# %%
odds.pop(0)
print(odds)
# Out:
# [3, 5, 7]

# %%
#to reverse the order of elements

# %%
odds.reverse()
print(odds)
# Out:
# [7, 5, 3]

# %%
odds_in_order= []
length_of_odds = len(odds)-1
for ii in range (0,len(odds)):
    odds_in_order.append(odds[length_of_odds-ii])
   
print(odds_in_order)
print('manually flipped back to normal', odds_in_order)
# Out:
# [3, 5, 7]
# manually flipped back to normal [3, 5, 7]

# %%
odds = [1,3,5,7]
primes = odds
primes.append(2)
#would be the same since shallow

# %%
binomial_name= "Drosophila melanogaster"
genus = binomial_name[0:10]

# %%
print (genus)
# Out:
# Drosophila

# %%
species = binomial_name[11:23]

# %%
print(species)
# Out:
# melanogaster

# %%
months = ['jan', 'feb', 'march', 'april', 'may', 'june', 'july', 'aug', 'sept', 'oct', 'nov', 'dec']

# %%
last_4_months = months[8:]

# %%
fall_month = months[8:len(months)-1]
print(fall_month)
# Out:
# ['sept', 'oct', 'nov']

# %%
#Conditions

# %%
num = 37

# %%
if num > 100.1:
    print('greater')
else:
    print('not_greater')
# Out:
# not_greater

# %%
#==: to check if something is true

# %%
#!= is not equal to

# %%
#>= greater than or equal to
#<= less thanor equal to

# %%
#get all even nmbers from 0 to 100
evens = []
for ii in range(1,101):
    if(ii% 2 == 0):
        evens.append.ii
        
print(evens)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-9d70b1304a03> in <module>
#       3 for ii in range(1,101):
#       4     if(ii% 2 == 0):
# ----> 5         evens.append.ii
#       6
#       7 print(evens)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'ii'
